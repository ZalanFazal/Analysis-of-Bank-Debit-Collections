# %%
from scipy.io import arff
import scipy as sc
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df1=pd.read_csv('1year.csv')
df2=pd.read_csv('2year.csv')
df3=pd.read_csv('3year.csv')
df4=pd.read_csv('4year.csv')
df5=pd.read_csv('5year.csv')
merged_df = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)
merged_df
# data processing
# Out:
#           Attr1    Attr2     Attr3    Attr4     Attr5    Attr6     Attr7  \
# 0      0.200550  0.37951  0.396410  2.04720   32.3510  0.38825  0.249760
# 1      0.209120  0.49988  0.472250  1.94470   14.7860  0.00000  0.258340
# 2      0.248660  0.69592  0.267130  1.55480   -1.1523  0.00000  0.309060
# 3      0.081483  0.30734  0.458790  2.49280   51.9520  0.14988  0.092704
# 4      0.187320  0.61323  0.229600  1.40630   -7.3128  0.18732  0.187320
# ...         ...      ...       ...      ...       ...      ...       ...
# 43400  0.012898  0.70621  0.038857  1.17220  -18.9070  0.00000  0.013981
# 43401 -0.578050  0.96702 -0.800850  0.16576  -67.3650 -0.57805 -0.578050
# 43402 -0.179050  1.25530 -0.275990  0.74554 -120.4400 -0.17905 -0.154930
# 43403 -0.108860  0.74394  0.015449  1.08780  -17.0030 -0.10886 -0.109180
# 43404 -0.105370  0.53629 -0.045578  0.91478  -56.0680 -0.10537 -0.109940
#
#          Attr8    Attr9    Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# ...

# %%
# explore data
merged_df.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     Attr9   Attr10  ...    Attr56   Attr57   Attr58    Attr59  Attr60  Attr61  \
# 0  1.1389  0.50494  ...  0.121960  0.39718  0.87804  0.001924  8.4160  5.1372
# 1  1.6996  0.49788  ...  0.121300  0.42002  0.85300  0.000000  4.1486  3.2732
# 2  1.3090  0.30408  ...  0.241140  0.81774  0.76599  0.694840  4.9909  3.9510
# 3  1.0571  0.57353  ...  0.054015  0.14207  0.94598  0.000000  4.5746  3.6147
# 4  1.1559  0.38677  ...  0.134850  0.48431  0.86515  0.124440  6.3985  4.3158
#
#     Attr62  Attr63   Attr64  class
# ...

# %%
merged_df.describe()
# Out:
#               Attr1         Attr2         Attr3         Attr4         Attr5  \
# count  43397.000000  43397.000000  43397.000000  43271.000000  4.331600e+04
# mean       0.035160      0.590212      0.114431      6.314702 -3.853466e+02
# std        2.994109      5.842748      5.439429    295.434425  6.124303e+04
# min     -463.890000   -430.870000   -479.960000     -0.403110 -1.190300e+07
# 25%        0.003429      0.268980      0.021521      1.049500 -4.908000e+01
# 50%        0.049660      0.471900      0.196610      1.569800 -1.034500e+00
# 75%        0.129580      0.688320      0.403390      2.787450  5.063425e+01
# max       94.280000    480.960000     28.336000  53433.000000  1.250100e+06
#
#               Attr6         Attr7         Attr8         Attr9        Attr10  \
# count  43397.000000  43397.000000  43311.000000  43396.000000  43397.000000
# mean      -0.056107      0.093478     12.640779      2.652166      0.626868
# ...

# %%
# checking missing and null values
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43405 entries, 0 to 43404
# Data columns (total 65 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Attr1   43397 non-null  float64
#  1   Attr2   43397 non-null  float64
#  2   Attr3   43397 non-null  float64
#  3   Attr4   43271 non-null  float64
#  4   Attr5   43316 non-null  float64
#  5   Attr6   43397 non-null  float64
#  6   Attr7   43397 non-null  float64
#  7   Attr8   43311 non-null  float64
#  8   Attr9   43396 non-null  float64
#  9   Attr10  43397 non-null  float64
#  10  Attr11  43361 non-null  float64
#  11  Attr12  43271 non-null  float64
#  12  Attr13  43278 non-null  float64
#  13  Attr14  43397 non-null  float64
#  14  Attr15  43369 non-null  float64
#  15  Attr16  43310 non-null  float64
#  16  Attr17  43311 non-null  float64
#  17  Attr18  43397 non-null  float64
#  18  Attr19  43277 non-null  float64
#  19  Attr20  43278 non-null  float64
# ...

# %%
# Here I will remove the null values 
merged_df.dropna()
merged_df.drop_duplicates()
# Out:
#           Attr1    Attr2     Attr3    Attr4     Attr5    Attr6     Attr7  \
# 0      0.200550  0.37951  0.396410  2.04720   32.3510  0.38825  0.249760
# 1      0.209120  0.49988  0.472250  1.94470   14.7860  0.00000  0.258340
# 2      0.248660  0.69592  0.267130  1.55480   -1.1523  0.00000  0.309060
# 3      0.081483  0.30734  0.458790  2.49280   51.9520  0.14988  0.092704
# 4      0.187320  0.61323  0.229600  1.40630   -7.3128  0.18732  0.187320
# ...         ...      ...       ...      ...       ...      ...       ...
# 43400  0.012898  0.70621  0.038857  1.17220  -18.9070  0.00000  0.013981
# 43401 -0.578050  0.96702 -0.800850  0.16576  -67.3650 -0.57805 -0.578050
# 43402 -0.179050  1.25530 -0.275990  0.74554 -120.4400 -0.17905 -0.154930
# 43403 -0.108860  0.74394  0.015449  1.08780  -17.0030 -0.10886 -0.109180
# 43404 -0.105370  0.53629 -0.045578  0.91478  -56.0680 -0.10537 -0.109940
#
#          Attr8    Attr9    Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# ...

# %%
# Here I replaced the null values by 0 value
merged_df.fillna(0)
# Out:
#           Attr1    Attr2     Attr3    Attr4     Attr5    Attr6     Attr7  \
# 0      0.200550  0.37951  0.396410  2.04720   32.3510  0.38825  0.249760
# 1      0.209120  0.49988  0.472250  1.94470   14.7860  0.00000  0.258340
# 2      0.248660  0.69592  0.267130  1.55480   -1.1523  0.00000  0.309060
# 3      0.081483  0.30734  0.458790  2.49280   51.9520  0.14988  0.092704
# 4      0.187320  0.61323  0.229600  1.40630   -7.3128  0.18732  0.187320
# ...         ...      ...       ...      ...       ...      ...       ...
# 43400  0.012898  0.70621  0.038857  1.17220  -18.9070  0.00000  0.013981
# 43401 -0.578050  0.96702 -0.800850  0.16576  -67.3650 -0.57805 -0.578050
# 43402 -0.179050  1.25530 -0.275990  0.74554 -120.4400 -0.17905 -0.154930
# 43403 -0.108860  0.74394  0.015449  1.08780  -17.0030 -0.10886 -0.109180
# 43404 -0.105370  0.53629 -0.045578  0.91478  -56.0680 -0.10537 -0.109940
#
#          Attr8    Attr9    Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# ...

# %%
# Visual view
sns.scatterplot(x='Attr1', y='Attr39', data=merged_df)
plt.show()

# %%
sns.histplot(merged_df['class'], bins=64, kde=True)
plt.title("Class distribution")
# Out:
# Text(0.5, 1.0, 'Class distribution')

# %%
sns.histplot(merged_df.Attr1,bins=10)
plt.show()

# %%
sns.heatmap(merged_df.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
merged_df.dropna()
sns.heatmap(merged_df.isnull(),cbar=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
filtered_data = merged_df[merged_df['Attr1'] > 3.00]

# Display the filtered data
filtered_data
merged_df.dropna()
# Out:
#           Attr1    Attr2     Attr3    Attr4    Attr5     Attr6     Attr7  \
# 0      0.200550  0.37951  0.396410  2.04720   32.351  0.388250  0.249760
# 8      0.009020  0.63202  0.053735  1.12630  -37.842  0.000000  0.014434
# 12     0.266690  0.34994  0.611470  3.02430   43.087  0.559830  0.332070
# 13     0.067731  0.19885  0.081562  2.95760   90.606  0.212650  0.078063
# 14    -0.029182  0.21131  0.452640  7.57460   57.844  0.010387 -0.034653
# ...         ...      ...       ...      ...      ...       ...       ...
# 43368  0.016964  0.75503  0.081574  1.12680 -197.070  0.002708  0.016964
# 43369  0.118540  0.51946  0.376420  1.96150  -80.058  0.000000  0.118540
# 43387  0.112350  1.73990 -0.514250  0.43445  -82.297 -0.322010  0.112350
# 43388 -0.089739  1.33000 -0.314680  0.67454 -124.530 -1.260700 -0.089739
# 43400  0.012898  0.70621  0.038857  1.17220  -18.907  0.000000  0.013981
#
#          Attr8   Attr9   Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# ...

# %%
plt.figure(figsize=(5,4))
plt.scatter(x='Attr1',y='Attr30',data=merged_df)
plt.xlabel('Attr1')
plt.ylabel('Attr2')
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.pairplot(merged_df,hue='species',diag_kind='kde')
plt.show()
